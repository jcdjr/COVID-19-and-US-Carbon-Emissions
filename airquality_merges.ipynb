# %%
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
aqi_2019 = pd.read_csv('data/air_quality/daily_aqi_2019.csv')
aqi_2019.head()
# Out:
#   State Name county Name  State Code  County Code       Date  AQI Category  \
# 0    Alabama     Baldwin           1            3   1/3/2019   18     Good
# 1    Alabama     Baldwin           1            3   1/6/2019   35     Good
# 2    Alabama     Baldwin           1            3   1/9/2019   14     Good
# 3    Alabama     Baldwin           1            3  1/12/2019   36     Good
# 4    Alabama     Baldwin           1            3  1/15/2019   38     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_2020 = pd.read_csv('data/air_quality/daily_aqi_2020.csv')
aqi_2020.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2020-01-01   48     Good
# 1    Alabama     Baldwin           1            3  2020-01-04   13     Good
# 2    Alabama     Baldwin           1            3  2020-01-07   14     Good
# 3    Alabama     Baldwin           1            3  2020-01-10   39     Good
# 4    Alabama     Baldwin           1            3  2020-01-13   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi_df = pd.merge(aqi_2019, aqi_2020, how = 'outer', on = ['State Name','county Name'])

# %%
aqi_df.head()
# Out:
#   State Name county Name  State Code_x  County Code_x    Date_x  AQI_x  \
# 0    Alabama     Baldwin           1.0            3.0  1/3/2019   18.0
# 1    Alabama     Baldwin           1.0            3.0  1/3/2019   18.0
# 2    Alabama     Baldwin           1.0            3.0  1/3/2019   18.0
# 3    Alabama     Baldwin           1.0            3.0  1/3/2019   18.0
# 4    Alabama     Baldwin           1.0            3.0  1/3/2019   18.0
#
#   Category_x Defining Parameter_x Defining Site_x  \
# 0       Good                PM2.5     01-003-0010
# 1       Good                PM2.5     01-003-0010
# 2       Good                PM2.5     01-003-0010
# 3       Good                PM2.5     01-003-0010
# 4       Good                PM2.5     01-003-0010
#
#    Number of Sites Reporting_x  State Code_y  County Code_y      Date_y  \
# 0                          1.0           1.0            3.0  2020-01-01
# 1                          1.0           1.0            3.0  2020-01-04
# ...

# %%
aqi_df.tail()
# Out:
#          State Name county Name  State Code_x  County Code_x Date_x  AQI_x  \
# 74353128  Wisconsin      Monroe           NaN            NaN    NaN    NaN
# 74353129  Wisconsin      Monroe           NaN            NaN    NaN    NaN
# 74353130  Wisconsin      Monroe           NaN            NaN    NaN    NaN
# 74353131  Wisconsin      Monroe           NaN            NaN    NaN    NaN
# 74353132  Wisconsin      Monroe           NaN            NaN    NaN    NaN
#
#          Category_x Defining Parameter_x Defining Site_x  \
# 74353128        NaN                  NaN             NaN
# 74353129        NaN                  NaN             NaN
# 74353130        NaN                  NaN             NaN
# 74353131        NaN                  NaN             NaN
# 74353132        NaN                  NaN             NaN
#
#           Number of Sites Reporting_x  State Code_y  County Code_y  \
# 74353128                          NaN          55.0           81.0
# ...

# %%
aqi = pd.merge(right = aqi_2019, left = aqi_2020, how = 'outer')

# %%
aqi.head()
# Out:
#   State Name county Name  State Code  County Code        Date  AQI Category  \
# 0    Alabama     Baldwin           1            3  2020-01-01   48     Good
# 1    Alabama     Baldwin           1            3  2020-01-04   13     Good
# 2    Alabama     Baldwin           1            3  2020-01-07   14     Good
# 3    Alabama     Baldwin           1            3  2020-01-10   39     Good
# 4    Alabama     Baldwin           1            3  2020-01-13   29     Good
#
#   Defining Parameter Defining Site  Number of Sites Reporting
# 0              PM2.5   01-003-0010                          1
# 1              PM2.5   01-003-0010                          1
# 2              PM2.5   01-003-0010                          1
# 3              PM2.5   01-003-0010                          1
# 4              PM2.5   01-003-0010                          1

# %%
aqi.tail()
# Out:
#        State Name county Name  State Code  County Code        Date  AQI  \
# 559654    Wyoming      Weston          56           45  12/27/2019   36
# 559655    Wyoming      Weston          56           45  12/28/2019   37
# 559656    Wyoming      Weston          56           45  12/29/2019   34
# 559657    Wyoming      Weston          56           45  12/30/2019   36
# 559658    Wyoming      Weston          56           45  12/31/2019   40
#
#        Category Defining Parameter Defining Site  Number of Sites Reporting
# 559654     Good              Ozone   56-045-0003                          2
# 559655     Good              Ozone   56-045-0003                          2
# 559656     Good              Ozone   56-045-0003                          2
# 559657     Good              Ozone   56-045-0003                          2
# 559658     Good              Ozone   56-045-0003                          2

# %%
aqi.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 559659 entries, 0 to 559658
# Data columns (total 10 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   State Name                 559659 non-null  object
#  1   county Name                559659 non-null  object
#  2   State Code                 559659 non-null  int64
#  3   County Code                559659 non-null  int64
#  4   Date                       559659 non-null  object
#  5   AQI                        559659 non-null  int64
#  6   Category                   559659 non-null  object
#  7   Defining Parameter         559659 non-null  object
#  8   Defining Site              559659 non-null  object
#  9   Number of Sites Reporting  559659 non-null  int64
# dtypes: int64(4), object(6)
# memory usage: 47.0+ MB

# %%
aqi.to_csv (r'C:\Users\18285\Desktop\aqi_merge.csv', index = False, header=True)

# %%
annual_2020 = pd.read_csv('data/air_quality/annual_aqi_by_county_2020.csv')
annual_2020.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2020            168        159              9
# 1  Alabama     Clay  2020             58         54              4
# 2  Alabama   DeKalb  2020            242        234              8
# 3  Alabama   Elmore  2020            149        149              0
# 4  Alabama   Etowah  2020            169        161              8
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
annual_2019 = pd.read_csv('data/air_quality/annual_aqi_by_county_2019.csv')
annual_2019.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2019            271        237             34
# 1  Alabama     Clay  2019            107         97             10
# 2  Alabama  Colbert  2019            263        252             11
# 3  Alabama   DeKalb  2019            361        324             37
# 4  Alabama   Elmore  2019            228        208             20
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
annual = pd.merge(right = annual_2019, left = annual_2020, how = 'outer')

# %%
annual.head()
# Out:
#      State   County  Year  Days with AQI  Good Days  Moderate Days  \
# 0  Alabama  Baldwin  2020            168        159              9
# 1  Alabama     Clay  2020             58         54              4
# 2  Alabama   DeKalb  2020            242        234              8
# 3  Alabama   Elmore  2020            149        149              0
# 4  Alabama   Etowah  2020            169        161              8
#
#    Unhealthy for Sensitive Groups Days  Unhealthy Days  Very Unhealthy Days  \
# 0                                    0               0                    0
# 1                                    0               0                    0
# 2                                    0               0                    0
# 3                                    0               0                    0
# 4                                    0               0                    0
#
#    Hazardous Days  Max AQI  90th Percentile AQI  Median AQI  Days CO  \
# ...

# %%
annual.tail()
# Out:
#         State      County  Year  Days with AQI  Good Days  Moderate Days  \
# 2085  Wyoming    Sublette  2019            365        266             88
# 2086  Wyoming  Sweetwater  2019            365        262            100
# 2087  Wyoming       Teton  2019            365        326             39
# 2088  Wyoming       Uinta  2019            365        315             49
# 2089  Wyoming      Weston  2019            365        340             25
#
#       Unhealthy for Sensitive Groups Days  Unhealthy Days  \
# 2085                                    8               3
# 2086                                    3               0
# 2087                                    0               0
# 2088                                    1               0
# 2089                                    0               0
#
#       Very Unhealthy Days  Hazardous Days  Max AQI  90th Percentile AQI  \
# 2085                    0               0      200                   71
# ...

# %%
annual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2090 entries, 0 to 2089
# Data columns (total 19 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   State                                2090 non-null   object
#  1   County                               2090 non-null   object
#  2   Year                                 2090 non-null   int64
#  3   Days with AQI                        2090 non-null   int64
#  4   Good Days                            2090 non-null   int64
#  5   Moderate Days                        2090 non-null   int64
#  6   Unhealthy for Sensitive Groups Days  2090 non-null   int64
#  7   Unhealthy Days                       2090 non-null   int64
#  8   Very Unhealthy Days                  2090 non-null   int64
#  9   Hazardous Days                       2090 non-null   int64
#  10  Max AQI                              2090 non-null   int64
# ...

# %%
annual.to_csv (r'C:\Users\18285\Desktop\annual_merge.csv', index = False, header=True)

# %%
n02_2020 = pd.read_csv('data/air_quality/n02_2020.csv')
n02_2020.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42602    1  33.553056
#
#    Longitude  Datum          Parameter Name Sample Duration  ... AQI  \
# 0    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  26
#
#   Method Code                                        Method Name  \
# 0         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
#
#     Local Site Name                                Address  State Name  \
# 0  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
#
#    County Name   City Name              CBSA Name  Date of Last Change
# 0    Jefferson  Birmingham  Birmingham-Hoover, AL           10/28/2020
#
# [1 rows x 29 columns]

# %%
n02_2019 = pd.read_csv('data/air_quality/n02_2019.csv')
n02_2019.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42602    1  33.553056
#
#    Longitude  Datum          Parameter Name Sample Duration  ... AQI  \
# 0    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...   8
#
#   Method Code                                        Method Name  \
# 0         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
#
#     Local Site Name                                Address  State Name  \
# 0  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
#
#    County Name   City Name              CBSA Name  Date of Last Change
# 0    Jefferson  Birmingham  Birmingham-Hoover, AL            6/12/2020
#
# [1 rows x 29 columns]

# %%
n02 = pd.merge(right = n02_2020, left = n02_2019, how = 'outer')

# %%
n02.head(1)
# Out:
#    State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 0           1           73        23           42602    1  33.553056
#
#    Longitude  Datum          Parameter Name Sample Duration  ... AQI  \
# 0    -86.815  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...   8
#
#   Method Code                                        Method Name  \
# 0         200  Teledyne-API Model 200EUP or T200UP - Photolyt...
#
#     Local Site Name                                Address  State Name  \
# 0  North Birmingham  NO. B'HAM,SOU R.R., 3009 28TH ST. NO.     Alabama
#
#    County Name   City Name              CBSA Name  Date of Last Change
# 0    Jefferson  Birmingham  Birmingham-Hoover, AL            6/12/2020
#
# [1 rows x 29 columns]

# %%
n02.tail(1)
# Out:
#         State Code  County Code  Site Num  Parameter Code  POC   Latitude  \
# 248182          72           61         6           42602    1  18.422595
#
#         Longitude  Datum          Parameter Name Sample Duration  ... AQI  \
# 248182 -66.120012  WGS84  Nitrogen dioxide (NO2)          1 HOUR  ...  12
#
#        Method Code                                        Method Name  \
# 248182         599  Instrumental - Chemiluminescence Teledyne API ...
#
#        Local Site Name           Address   State Name  County Name  City Name  \
# 248182             NaN  De Diego Highway  Puerto Rico     Guaynabo   Guaynabo
#
#                            CBSA Name  Date of Last Change
# 248182  San Juan-Carolina-Caguas, PR             9/2/2020
#
# [1 rows x 29 columns]

# %%
n02.to_csv (r'C:\Users\18285\Desktop\n02_merge.csv', index = False, header=True)
